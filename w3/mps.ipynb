# %% [markdown]
# Make sure to make a new venv with the nightly build of PyTorch to enable MPS. <br>
#
# Download with:
# ```
# # pip3 install --pre torch torchvision --index-url https://download.pytorch.org/whl/nightly/cpu
# ```

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

import numpy as np

# %%
mps_device = torch.device("mps")

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./', train=True,
                                        download=False, transform=transform,)    
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./', train=False,
                                       download=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# /Users/bea/Documents/University/Y2/T2/Artificial-Intelligence/metal-venv/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
# Check that MPS is available
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")

else:
    mps_device = torch.device("mps")

    

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        # New - x to mps
        x = x.to(mps_device) 
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()
net = net.to(mps_device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        
        # Something around here needs to be also put to mps?
        # Getting new error:
        # RuntimeError: Placeholder storage has not been allocated on MPS device!

        # Because of the syntax with x = x.to syntax I tried something like this
        # inp = inputs.to(mps_device)
        # lab = labels.to(mps_device)
        # inp, lab = data;
       
        inputs, labels = data
        optimizer.zero_grad()

        # then tried to put these new variables in here:
        # outputs = net(inp)
        # loss = criterion(outputs, lab)
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

       

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 17
#      15 # forward + backward + optimize
#      16 outputs = net(inputs)
# ---> 17 loss = criterion(outputs, labels)
#      18 loss.backward()
#      19 optimizer.step()
#
# File ~/Documents/University/Y2/T2/Artificial-Intelligence/metal-venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/University/Y2/T2/Artificial-Intelligence/metal-venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/Documents/University/Y2/T2/Artificial-Intelligence/metal-venv/lib/python3.13/site-packages/torch/nn/modules/loss.py:1394, in CrossEntropyLoss.forward(self, input, target)
#    1392 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#    1393     """Runs the forward pass."""
# -> 1394     return F.cross_entropy(
#    1395         input,
#    1396         target,
#    1397         weight=self.weight,
#    1398         ignore_index=self.ignore_index,
#    1399         reduction=self.reduction,
#    1400         label_smoothing=self.label_smoothing,
#    1401     )
#
# File ~/Documents/University/Y2/T2/Artificial-Intelligence/metal-venv/lib/python3.13/site-packages/torch/nn/functional.py:3504, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3502 if size_average is not None or reduce is not None:
#    3503     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3504 return torch._C._nn.cross_entropy_loss(
#    3505     input,
#    3506     target,
#    3507     weight,
#    3508     # pyrefly: ignore [bad-argument-type]
#    3509     _Reduction.get_enum(reduction),
#    3510     ignore_index,
#    3511     label_smoothing,
#    3512 )
#
# RuntimeError: Placeholder storage has not been allocated on MPS device!
